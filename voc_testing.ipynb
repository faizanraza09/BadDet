# %%
# %cd yolov5
# Out:
# /home/dak515/Desktop/mr5985/yolo_training/yolov5

# %%
# !python3 val.py --weights runs/train/exp37/weights/best.pt --data VOC.yaml --task "test" --device 0,3
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC.yaml, weights=['runs/train/exp37/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC/labels/tes
#                  Class     Images  Instances          P          R      mAP50
#                    all       4952      12032      0.811      0.781      0.828      0.592
# ...

# %%
# !python3 val.py --weights runs/train/exp45/weights/best.pt --data VOC.yaml --task "test" --device 0,3
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC.yaml, weights=['runs/train/exp45/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC/labels/tes
#                  Class     Images  Instances          P          R      mAP50
#                    all       4952      12032      0.806      0.763       0.82      0.581
# ...

# %%
# !python3 val.py --weights runs/train/exp46/weights/best.pt --data VOC.yaml --task "test" --device 0,3
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC.yaml, weights=['runs/train/exp46/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC/labels/tes
#                  Class     Images  Instances          P          R      mAP50
#                    all       4952      12032      0.687      0.645      0.693      0.382
# ...

# %%
# !python3 val.py --weights runs/train/exp54/weights/best.pt --data VOC.yaml --task "test" --device 0,3
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC.yaml, weights=['runs/train/exp54/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC/labels/tes
#                  Class     Images  Instances          P          R      mAP50
#                    all       4952      12032      0.708      0.657        0.7      0.426
# ...

# %%
# !python3 val.py --weights runs/train/exp53/weights/best.pt --data VOC.yaml --task "test" --device 0,3
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC.yaml, weights=['runs/train/exp53/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC/labels/tes
#                  Class     Images  Instances          P          R      mAP50
#                    all       4952      12032        0.8      0.774      0.821      0.582
# ...

# %%
# !python3 val.py --weights runs/train/exp45/weights/best.pt --data VOC_OGA.yaml --task "test" --device 0,3
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC_OGA.yaml, weights=['runs/train/exp45/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC_OGA/labels
#                  Class     Images  Instances          P          R      mAP50
#                    all       4952      12032      0.806      0.764      0.817      0.577
# ...

# %%
# !python3 val.py --weights runs/train/exp46/weights/best.pt --data VOC_RMA.yaml --task "test" --device 0,3
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC_RMA.yaml, weights=['runs/train/exp46/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC_RMA/labels
#                  Class     Images  Instances          P          R      mAP50
#                    all       4952      12032      0.682      0.628      0.679      0.372
# ...

# %%
# !python3 val.py --weights runs/train/exp54/weights/best.pt --data VOC_GMA.yaml --task "test" --device 0,3 --save-txt
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC_GMA.yaml, weights=['runs/train/exp54/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC_GMA/labels
#                  Class     Images  Instances          P          R      mAP50   2 42
# 1 88
# 5 102
# 2 49
# 1 21
# 2 48
# 1 61
# 1 34
# 5 129
# 3 118
# 8 118
# 1 24
# 1 20
# 1 36
# 1 34
# 1 45
# 1 31
# 1 22
# ...

# %%
# !python3 val.py --weights runs/train/exp53/weights/best.pt --data VOC_ODA.yaml --task "test" --device 2 --batch-size 1
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC_ODA.yaml, weights=['runs/train/exp53/weights/best.pt'], batch_size=1, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=test, device=2, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:2 (NVIDIA RTX A6000, 48677MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC_ODA/labels
#                  Class     Images  Instances          P          R      mAP50   2 8
#                  Class     Images  Instances          P          R      mAP50

# %%
# !python3 val.py --weights runs/train/exp53/weights/best.pt --data VOC_ODA.yaml --task "test" --device 0,3 --save-txt --conf-thres 0.5
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC_ODA.yaml, weights=['runs/train/exp53/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.5, iou_thres=0.5, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ confidence threshold 0.5 > 0.001 produces invalid results
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC_ODA/labels
#                  Class     Images  Instances          P          R      mAP50
# ...

# %%
# !python3 val.py --weights runs/train/exp45/weights/best.pt --data VOC_OGA.yaml --task "test" --device 0,3 --save-txt --conf-thres 0.5
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC_OGA.yaml, weights=['runs/train/exp45/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.5, iou_thres=0.6, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ confidence threshold 0.5 > 0.001 produces invalid results
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC_OGA/labels
#                  Class     Images  Instances          P          R      mAP50
# ...

# %%
# !python3 val.py --weights runs/train/exp46/weights/best.pt --data VOC_RMA.yaml --task "test" --device 0,3 --save-txt --conf-thres 0.5
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC_RMA.yaml, weights=['runs/train/exp46/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.5, iou_thres=0.6, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ confidence threshold 0.5 > 0.001 produces invalid results
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC_RMA/labels
#                  Class     Images  Instances          P          R      mAP50
# ...

# %%
# !python3 val.py --weights runs/train/exp54/weights/best.pt --data VOC_GMA.yaml --task "test" --device 0,3 --save-txt --conf-thres 0.5
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC_GMA.yaml, weights=['runs/train/exp54/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.5, iou_thres=0.6, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ confidence threshold 0.5 > 0.001 produces invalid results
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC_GMA/labels
#                  Class     Images  Instances          P          R      mAP50
# ...

# %%
# !python3 val.py --weights runs/train/exp53/weights/best.pt --data VOC_ODA.yaml --task "test" --device 0,3 --save-txt --conf-thres 0.5 --conf-thres 0.5
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC_ODA.yaml, weights=['runs/train/exp53/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.5, iou_thres=0.6, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ confidence threshold 0.5 > 0.001 produces invalid results
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC_ODA/labels
#                  Class     Images  Instances          P          R      mAP50
# ...

# %%
# !python3 val.py --weights runs/train/exp69/weights/best.pt --data VOC_OGA.yaml --task "test" --device 0,3 --save-txt --conf-thres 0.5
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC_OGA.yaml, weights=['runs/train/exp69/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.5, iou_thres=0.6, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ confidence threshold 0.5 > 0.001 produces invalid results
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC_OGA/labels
#                  Class     Images  Instances          P          R      mAP50
# ...

# %%
# !python3 val.py --weights runs/train/exp71/weights/best.pt --data VOC_OGA.yaml --task "test" --device 0,3 --save-txt --conf-thres 0.5
# Out:
# val: data=/home/dak515/Desktop/mr5985/yolo_training/yolov5/data/VOC_OGA.yaml, weights=['runs/train/exp71/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.5, iou_thres=0.6, max_det=300, task=test, device=0,3, workers=8, single_cls=False, augment=False, verbose=False, save_txt=True, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING ⚠️ confidence threshold 0.5 > 0.001 produces invalid results
# YOLOv5 🚀 v7.0-287-g574331f9 Python-3.8.10 torch-2.0.1+cu118 CUDA:0 (NVIDIA RTX A6000, 48677MiB)
#                                                              CUDA:3 (NVIDIA RTX A6000, 48674MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# test: Scanning /home/dak515/Desktop/mr5985/yolo_training/datasets/VOC_OGA/labels
#                  Class     Images  Instances          P          R      mAP50
# ...
